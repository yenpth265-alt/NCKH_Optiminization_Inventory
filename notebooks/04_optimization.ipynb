# %%
import sys
import os
import pandas as pd
sys.path.append('../src')
from budget_constraint import optimize_procurement_greedy

# 1. Đọc kết quả đã dự báo từ file 03 (Rất nhẹ, không tốn RAM)
df_forecast = pd.read_csv('../dataset/outputs/forecast_results.csv')

# 2. Gọi hàm Budget đã đóng gói
MY_BUDGET = 1000000
total_profit, selected_items = optimize_procurement_greedy(df_forecast, MY_BUDGET)

# 3. In kết quả
print(f"💰 Tổng lợi nhuận tối ưu: {total_profit:,.2f}")
print(f"📦 Danh sách nhập hàng: {len(selected_items)} mã hàng")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.13.7' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
